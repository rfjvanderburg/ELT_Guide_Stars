# %% [markdown]
# # Illustration of H-band magnitude predictor based on PS1 + Gaia, trained using H-band information from VIKING and VVV
#
# ### Rationale
# For the ELT to operate we will need reference star catalogues with information in the optical and Near-IR. Since not the entire sky that will be accessible by the ELT is covered with deep (few mag beyond 2MASS) NIR imaging surveys, we explore the possibility to predict the missing information using data that is available in the optical.
#
# Here we assume that Gaia overlap is essential to be able to track stellar proper motions. We note that proper motions are typically of order 10 mas/year which is substantial compared to the ELT instrumental pixel scale and diffraction-limited PSF FWHM.
#
# In practise we input colours, rather than magnitudes, to have a more robust prediction. The final value is a G-H colour, where capital G is the Gaia very broad G-band. The predicted H-band is simply the total G-band mangnitudes minus G-H colour.
#
# ### Obtaining and Cleaning the data
# We run basic SQL functions to query the CDS/Vizier databases. Restart connection whenever connection is lost (up to 5 times per query).\\
# We require all colours to be measured (no NaNs, which implies detections in all optical bands). Similar cleaning will need to be done on the final data set when this model will be applied.\\
# We also remove stars for which the H-magnitude is brighter than 13.0. That is the approximate saturation limit in the VISTA+VVV surveys.
#
# ### Model used
# We use a basic Neural Network to map the input vector (i.e. available colours in the optical), to a single float value that represents the G-H colour.
#
# To optimise the performance we searched over various NN architectures, either one, two or three fully connected hidden layers. Two layers with 32 units gave a good performance on the cross validation set (0.1 mean absolute error). More complexity (layers and/or neurons) only improved the performance on the training set, and not on the CV set; indication of overfitting. The performance degrades for two layers of 16 units each. Each unit in the hidden layer has a ReLU activation function, with a final single unit with a linear activation to give the prediction.
#
# ### Model used
# Performance is generally good: 0.1 mag mean absolute error. Slightly better performance for VIKING than VVV (highly extincted region of the Galactic centre).
# Objects that are extreme outliers generally have non-standard colours (as shown in pairplots). These should be flagged beforehand to identify an uncertain H-band prediction

# %% [markdown]
# # Load function and Modules

# %%
# BASIC FUNCTIONS AND MODULES
import seaborn as sns
import sys
import math
import pandas as pd
pd.set_option('max_columns', None)
import numpy as np
import six
from pyvo.dal import tap
from matplotlib.pylab import plt
import time
import pydot

# Astropy
from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy.units import Quantity
from astropy.coordinates.tests.utils import randomly_sample_sphere
from astroquery.esasky import ESASky
from astropy.coordinates import match_coordinates_sky
from astropy.stats import sigma_clipped_stats

#Tensorflow specific
# Make numpy printouts easier to read.
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers.experimental import preprocessing


#SQL setup
VIZIER_TAP_CAT = "http://tapvizier.u-strasbg.fr/TAPVizieR/tap"
tapcatvizier = tap.TAPService(VIZIER_TAP_CAT)
def query_Gaia_PS1(ra_search, dec_search, halfboxsize):
    minra = ra_search-halfboxsize
    maxra = ra_search+halfboxsize
    mindec = dec_search-halfboxsize
    maxdec = dec_search+halfboxsize
    query="""SELECT RA_ICRS, DE_ICRS, gaia.Gmag, "BP-RP" as BPmRP, "BP-G" as BPmG, RUWE, epsi, sepsi, 
    ps1.gmag-rmag as gmr, rmag-imag as rmi, imag-zmag as imz, zmag-ymag as zmy, gaia.Gmag-rmag as Gmr,
    "b_rmag" as rmagmin, "B_rmag" as rmagmax
    FROM "I/350/gaiaedr3" AS Gaia, "II/349/ps1" as PS1
    WHERE RA_ICRS > %f AND RA_ICRS < %f AND DE_ICRS > %f AND DE_ICRS < %f AND objID = PS1"""  % (minra, maxra, mindec, maxdec) 
    res = runqueryvizier(query)
    df_vizier = res.to_table().to_pandas()
    return df_vizier

def query_virac(ra_search, dec_search, halfboxsize):
    minra = ra_search-halfboxsize
    maxra = ra_search+halfboxsize
    mindec = dec_search-halfboxsize
    maxdec = dec_search+halfboxsize
    query="""SELECT RA_ICRS as RAJ2000, DE_ICRS as DEJ2000, Ymag, Jmag, Hmag, Ksmag 
    FROM "II/364/virac" 
    WHERE RA_ICRS > %f AND RA_ICRS < %f AND DE_ICRS > %f AND DE_ICRS < %f"""  % (minra, maxra, mindec, maxdec) 
    res = runqueryvizier(query)
    df_vizier = res.to_table().to_pandas()
    return df_vizier

def query_viking(ra_search, dec_search, halfboxsize):
    minra = ra_search-halfboxsize
    maxra = ra_search+halfboxsize
    mindec = dec_search-halfboxsize
    maxdec = dec_search+halfboxsize
    query="""SELECT RAJ2000, DEJ2000, Yap3 as Ymag, Jap3 as Jmag, Hap3 as Hmag, Ksap3 as Ksmag
    FROM "II/343/viking2" 
    WHERE RAJ2000 > %f AND RAJ2000 < %f AND DEJ2000 > %f AND DEJ2000 < %f"""  % (minra, maxra, mindec, maxdec) 
    res = runqueryvizier(query) 
    df_vizier = res.to_table().to_pandas()
    return df_vizier

def runqueryvizier(query):
    """Make sure the query runs, even if connection is lost. Retry a few times"""
    retry_flag = True
    retry_count = 0
    while retry_flag and retry_count < 5:
        try:
            res = tapcatvizier.search(query=query)
            retry_flag = False
        except Exception as e:
            print (e)
            print ("Retry after 5 sec")
            retry_count = retry_count + 1
            time.sleep(5)
    return res

# %% [markdown]
# # Fill dataframe for training and testing

# %%
df_master1 = pd.DataFrame({})

boxsize = 0.05

# First area of high extinction from VVV (VIRAC)
for racent in np.arange(264.,278.,13.9/3.):
    for deccent in np.arange(-29.,-24.,2.4):
        df_VISTA = query_virac(racent,deccent,boxsize).dropna().reset_index().drop(columns='index')
        df_GaiaPS1 = query_Gaia_PS1(racent,deccent,boxsize).dropna().reset_index().drop(columns='index')       
        if len(df_GaiaPS1) > 0.5 and len(df_VISTA) > 0.5:
            c = SkyCoord(ra=df_VISTA['RAJ2000']*u.degree, dec=df_VISTA['DEJ2000']*u.degree)
            catalog = SkyCoord(ra=df_GaiaPS1['RA_ICRS']*u.degree, dec=df_GaiaPS1['DE_ICRS']*u.degree)
            idx, d2d, d3d = catalog.match_to_catalog_sky(c)
            selarr=((d2d.arcsec <0.5))
            df_GaiaPS1.loc[selarr,'matchdistarcsecVISTA']=d2d[selarr].arcsec
            df_GaiaPS1_cut = df_GaiaPS1.loc[selarr.nonzero()].reset_index()
            df_VISTA_cut = df_VISTA.loc[idx[selarr.nonzero()[0]]].reset_index()
            df_new = df_GaiaPS1_cut.merge(df_VISTA_cut, left_index=True, right_index=True, how='right').drop(columns=['index_x','index_y'])
            df_master1 = df_master1.append(df_new)

# %%
df_master2 = pd.DataFrame({})

# Now area of low extinction from VIKING
boxsize = 0.25
for racent in np.arange(129.,140.,10.9/6):
    for deccent in np.arange(-2.,2.,3.9/3):
        df_VISTA = query_viking(racent,deccent,boxsize).dropna().reset_index().drop(columns='index')
        df_GaiaPS1 = query_Gaia_PS1(racent,deccent,boxsize).dropna().reset_index().drop(columns='index')       
        if len(df_GaiaPS1) > 0.5 and len(df_VISTA) > 0.5:
            c = SkyCoord(ra=df_VISTA['RAJ2000']*u.degree, dec=df_VISTA['DEJ2000']*u.degree)
            catalog = SkyCoord(ra=df_GaiaPS1['RA_ICRS']*u.degree, dec=df_GaiaPS1['DE_ICRS']*u.degree)
            idx, d2d, d3d = catalog.match_to_catalog_sky(c)
            selarr=((d2d.arcsec <0.50))
            df_GaiaPS1.loc[selarr,'matchdistarcsecVISTA']=d2d[selarr].arcsec
            df_GaiaPS1_cut = df_GaiaPS1.loc[selarr.nonzero()].reset_index()
            df_VISTA_cut = df_VISTA.loc[idx[selarr.nonzero()[0]]].reset_index()
            df_new = df_GaiaPS1_cut.merge(df_VISTA_cut, left_index=True, right_index=True, how='right').drop(columns=['index_x','index_y'])
            df_master2 = df_master2.append(df_new)

# %%
df_master = pd.DataFrame({})
df_master = df_master.append(df_master1)
df_master = df_master.append(df_master2)

len(df_master)
# Out:
# 52113

# %% [markdown]
# # Clean dataframe and prepare for training

# %%
df_master = df_master.reset_index().drop(columns='index')
df_master['GmH'] = df_master['Gmag']-df_master['Hmag']
#brighter than 13 is saturated. Doesn't work for training purposes
df_master = df_master[(df_master['Hmag'] > 13.0) & (df_master['Gmag'] > 13.0)].reset_index().drop(columns='index')

# %%
df_master.tail()
# Out:
#           RA_ICRS   DE_ICRS       Gmag    BPmRP      BPmG   RUWE   epsi  \
# 47317  139.663811  2.021431  19.812599  1.21776  0.578981  1.027  0.000
# 47318  139.656812  2.030252  19.822599  1.90125  0.949423  1.085  1.291
# 47319  139.680610  2.034670  16.653900  1.19320  0.524513  1.130  0.206
# 47320  139.681898  2.048201  19.091801  2.34925  1.267970  0.956  0.000
# 47321  139.692648  2.049855  17.718300  1.40319  0.639385  1.044  0.225
#
#           sepsi     gmr     rmi     imz     zmy     Gmr    rmagmin    rmagmax  \
# 47317  0.000000  0.8025  0.2895  0.1503  0.0676  0.0553  19.689501  19.815399
# 47318  1.559917  1.1138  0.5980  0.2534  0.2015 -0.0391  19.712200  20.010401
# 47319  1.818739  0.6914  0.2804  0.1083  0.0910  0.0386  16.601000  16.632799
# 47320  0.000000  1.2541  1.0217  0.4516  0.1903 -0.3406  19.367901  19.633699
# 47321  0.703819  0.8925  0.3495  0.1428  0.1064  0.0451  17.650499  17.705000
#
#        matchdistarcsecVISTA    RAJ2000  DEJ2000     Ymag       Jmag  \
# 47317              0.206364  139.66384  2.02148  18.5475  18.141500
# 47318              0.218797  139.65683  2.03031  18.1084  17.673599
# 47319              0.184236  139.68062  2.03472  15.4512  15.141800
# 47320              0.361731  139.68196  2.04828  17.0230  16.527700
# 47321              0.197218  139.69268  2.04990  16.3616  16.037901
#
#             Hmag      Ksmag       GmH
# 47317  17.528099  17.804701  2.284500
# 47318  16.997900  16.844601  2.824699
# 47319  14.582500  14.565800  2.071400
# 47320  16.062500  15.877200  3.029301
# 47321  15.529400  15.353900  2.188900

# %% [markdown]
# # Prepare Tensorflow

# %%
#Random split. Important since VVV and VISTA sources are not mixed
train_dataset = df_master.sample(frac=0.8, random_state=0)
test_dataset = df_master.drop(train_dataset.index)

# %%
train_dataset.describe().transpose()
# Out:
#                         count        mean         std         min         25%  \
# RA_ICRS               37858.0  199.760101   69.719512  128.750151  131.012371
# DE_ICRS               37858.0  -12.816029   13.453482  -29.049992  -26.599557
# Gmag                  37858.0   18.553156    1.371144   13.406200   17.724975
# BPmRP                 37858.0    1.703921    0.657938   -1.082950    1.214322
# BPmG                  37858.0    0.750979    0.437264   -2.183530    0.421679
# RUWE                  37858.0    1.153896    0.575983    0.771000    0.990000
# epsi                  37858.0    0.617771    0.984516    0.000000    0.000000
# sepsi                 37858.0    6.955248  101.922984    0.000000    0.000000
# gmr                   37858.0    1.034011    0.533779   -5.793800    0.680325
# rmi                   37858.0    0.610485    0.397738   -1.219200    0.293100
# imz                   37858.0    0.323941    0.243070   -3.794100    0.138300
# zmy                   37858.0    0.185344    0.179424   -3.849000    0.078700
# Gmr                   37858.0   -0.147646    0.257236   -3.284600   -0.293400
# rmagmin               37858.0   18.643154    1.414122   13.574400   17.824499
# rmagmax               37858.0   18.776712    1.502604   13.574400   17.882225
# matchdistarcsecVISTA  37858.0    0.121472    0.070959    0.000430    0.075048
# RAJ2000               37858.0  199.760114   69.719513  128.750150  131.012418
# DEJ2000               37858.0  -12.816011   13.453478  -29.049965  -26.599539
# Ymag                  37858.0   16.804369    1.325544   10.956000   15.787000
# Jmag                  37858.0   16.336489    1.373900    9.472000   15.261775
# Hmag                  37858.0   15.797290    1.440891   13.000300   14.678000
# Ksmag                 37858.0   15.622525    1.469167    7.478000   14.501075
# GmH                   37858.0    2.755868    0.973103  -11.522700    2.039400
#
#                              50%         75%           max
# RA_ICRS               139.859911  273.254481    277.949990
# DE_ICRS                -2.009040   -0.474592      2.149903
# Gmag                   18.751350   19.561501     20.926399
# BPmRP                   1.616460    2.160900      5.938830
# BPmG                    0.676638    1.010118      4.192920
# RUWE                    1.030000    1.094000     31.326000
# epsi                    0.216000    0.854000     12.264000
# sepsi                   0.378924    1.958428  15651.424000
# gmr                     1.014000    1.248200      9.547300
# rmi                     0.500500    0.926800      4.232200
# imz                     0.284600    0.493300      3.629500
# zmy                     0.168500    0.272175      4.425600
# Gmr                    -0.066600    0.020800      2.494600
# rmagmin                18.846701   19.678101     22.168600
# rmagmax                18.948650   19.846075     26.308300
# matchdistarcsecVISTA    0.109797    0.149473      0.499855
# RAJ2000               139.859910  273.254465    277.949997
# DEJ2000                -2.009040   -0.474575      2.149840
# Ymag                   16.933600   17.806075     20.209000
# Jmag                   16.464001   17.364151     20.396601
# Hmag                   15.940000   16.879999     27.298000
# Ksmag                  15.779000   16.718851     19.782700
# GmH                     2.702900    3.319700      7.282300

# %%
train_features = train_dataset[['BPmRP','BPmG','gmr','rmi','imz','zmy','Gmr']]
test_features = test_dataset[['BPmRP','BPmG','gmr','rmi','imz','zmy','Gmr']]

train_labels = train_dataset['GmH']
test_labels = test_dataset['GmH']

# %%
sns.pairplot(train_features)

# %%
# Normalise data
normalizer = preprocessing.Normalization(axis=-1)
normalizer.adapt(np.array(train_features))
print(normalizer.mean.numpy())
# Out:
# [ 1.7039213   0.7509795   1.034011    0.6104853   0.3239409   0.18534398
#  -0.14764626]

# %%
def build_and_compile_model(norm):
    """This sets up the NN. Can try different architectures."""
    model = keras.Sequential([
      norm,
      layers.Dense(32, activation='relu'),
      layers.Dense(32, activation='relu'),
      layers.Dense(1)
    ])

    model.compile(loss='mean_absolute_error',
                optimizer=tf.keras.optimizers.Adam(0.0003))
    return model

def plot_loss(history):
    """Check performance"""
    plt.plot(history.history['loss'], label='loss')
    plt.plot(history.history['val_loss'], label='val_loss')
    plt.ylim([0.07, 0.3])
    plt.xlabel('Epoch')
    plt.ylabel('Error [Hmag]')
    plt.yscale('log')
    plt.legend()
    plt.grid(True)

# %% [markdown]
# # Set up and train model

# %%
dnn_model = build_and_compile_model(normalizer)
dnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# normalization (Normalization (None, 7)                 15
# _________________________________________________________________
# dense (Dense)                (None, 32)                256
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 1,360
# Trainable params: 1,345
# Non-trainable params: 15
# _________________________________________________________________

# %%
# %%time
history = dnn_model.fit(
    train_features, train_labels,
    validation_split=0.2,
    verbose=0, epochs=400)
# Out:
# CPU times: user 7min 18s, sys: 1min 33s, total: 8min 51s
# Wall time: 4min 44s

# %%
#Check performance
#32, 32, learning rate 0.0003, i.e. basic model
plot_loss(history)
print(history.history['val_loss'][-1])
# Out:
# 0.0923842266201973

# %% [markdown]
# # Make predictions

# %%
test_predictions = dnn_model.predict(test_features).flatten()
test_dataset['Hmag_predict'] = test_dataset['Gmag']-test_predictions
test_dataset['Gmy'] = test_dataset['Gmr']+test_dataset['rmi']+test_dataset['imz']+test_dataset['zmy']

# %%
plt.scatter(test_dataset['Hmag'],test_dataset['Hmag']-test_dataset['Hmag_predict'],marker='.')
plt.xlim(13,20)
plt.ylim(-1.4,1.4)
SEL = test_dataset['DE_ICRS'] > -5.
plt.scatter(test_dataset[SEL]['Hmag'],test_dataset[SEL]['Hmag']-test_dataset[SEL]['Hmag_predict'],marker='.')
plt.show()

# %%
bins=np.linspace(-0.5,0.5,100)
plt.hist(test_dataset[~SEL]['Hmag']-test_dataset[~SEL]['Hmag_predict'],density=True,bins=bins, label='VVV')
plt.hist(test_dataset[SEL]['Hmag']-test_dataset[SEL]['Hmag_predict'],density=True,bins=bins,alpha=0.5, label='VIKING')
plt.legend()
plt.show()

# %% [markdown]
# # Explore problems

# %%
# There seems to be a MAGZP problem with part of the VIKING dataset. 
plt.scatter(test_dataset['RA_ICRS'], test_dataset['DE_ICRS'], marker='.')
plt.xlim(127.5,142.5)
plt.ylim(-3,3)
SEL = (test_dataset['Hmag']-test_dataset['Hmag_predict'] < -0.3)
np.sum(SEL)
plt.scatter(test_dataset[SEL]['RA_ICRS'], test_dataset[SEL]['DE_ICRS'], marker='.')
# Conclusion: the VIKING dataset likely has a patch with a zeropoint that is off by 0.4 magnitude. Alternatively, there could be a problem with Gaia and/or PS1 photometry in that patch. The fraction is sources that are wrong is probably low enough that it does not affect our best-fit model too much.

# %%
# Now look at extreme outliers, 0.2 % of the test dataset
SEL = (test_dataset['Hmag'] < 18.) & (abs(test_dataset['Hmag']-test_dataset['Hmag_predict']) > 1.0)
test_dataset['mark'] = 'normal'
test_dataset.loc[SEL,'mark'] = 'outlier'
print(np.sum(SEL))
print(np.sum(SEL)/len(test_dataset))
# Out:
# 18
# 0.0019019442096365174

# %%
test_dataset[SEL]
# Out:
#           RA_ICRS    DE_ICRS       Gmag     BPmRP      BPmG   RUWE   epsi  \
# 586    264.020923 -28.974117  20.662300  1.985010  0.165049  1.027  2.637
# 853    263.992541 -28.972351  18.859400  3.555040  1.876730  1.690  2.506
# 870    263.998440 -28.958275  20.377199  3.095310  1.527820  1.148  1.941
# 943    263.971195 -28.951733  18.455799  4.696510  3.109160  0.980  0.178
# 1246   264.031406 -26.618336  20.458000  2.454620  1.011320  1.183  3.783
# 1873   263.953873 -26.623386  19.353001  2.949450  1.942570  1.089  0.994
# 1998   263.976452 -26.604993  19.239799  0.762251 -0.373653  0.939  0.000
# 4490   263.967712 -24.168178  16.010401  2.565220  1.356580  1.035  0.000
# 6849   268.605365 -26.644591  20.621201  2.287350  1.038230  0.988  0.000
# 6879   268.611633 -26.633411  19.239100  2.632210  1.403100  1.108  1.042
# 7015   268.675899 -26.613698  18.253401  2.423230  1.261560  1.049  0.475
# 7087   268.621792 -26.606186  20.516500  2.081300  1.018650  1.137  3.116
# 7412   268.608824 -24.246075  20.486601  1.930840  0.679644  1.151  2.194
# 16119  277.871974 -29.029083  16.805300  1.384020  0.638597  1.055  0.000
# 33002  130.629658   0.569554  13.807700  0.772499  0.303598  1.257  0.089
# 34201  130.629091   1.686718  13.585500  0.981740  0.407237  0.989  0.000
# 36519  132.873637   0.691594  19.048100  2.885640  1.625360  1.002  0.573
# 39346  134.356245   0.832408  17.769100  2.545800  1.403940  1.089  0.232
#
#               sepsi     gmr     rmi     imz     zmy     Gmr    rmagmin  \
# 586    1.670506e+00 -1.6158  1.9155  1.2602  0.6990 -1.0598  21.673500
# 853    1.870307e+01  2.9819  1.4296  0.9320  0.7602 -0.7042  19.433500
# 870    1.222004e+00 -0.1702  2.5246  0.7783  0.4624 -1.6034  20.537001
# 943    1.968328e-01  2.0844  2.7140  1.4529  0.8973 -2.3168  20.765699
# 1246   3.979932e+00  0.7704  1.2776  0.5635  0.3222 -0.5537  20.767799
# 1873   1.550271e+00  0.9871  1.3285  0.6039  0.4137 -0.6874  19.994400
# 1998   0.000000e+00  1.8048  1.1822  0.6490  0.3340 -0.5331  19.680500
# 4490   2.389307e-15  1.6368  0.9907  0.5924  0.4147 -0.3919  16.398199
# 6849   0.000000e+00  0.9114  1.2499  0.7121  0.3785 -0.5337  21.106899
# 6879   2.809140e+00  1.1883  1.3058  0.6558  0.3370 -0.5842  19.778700
# 7015   2.200848e+00  1.4637  0.8206  0.5517  0.4975 -0.2057  18.427900
# 7087   3.459331e+00  6.7672  1.1636  0.7196  0.5296 -0.5523  20.821800
# 7412   1.582954e+00  0.8066  1.1702  0.6486  0.3154 -0.3945  20.797501
# 16119  2.807296e-15  0.8320  0.3448  0.1982  0.1219 -0.0149  16.814800
# 33002  5.197514e+00  0.2600  0.1923  0.0234  0.0227 -0.0886  13.896300
# 34201  0.000000e+00  0.5094  0.1878  0.0892  0.0422  0.0107  13.567000
# 36519  1.362411e+00  1.2678  1.5343  0.6822  0.3181 -0.7739  19.773001
# 39346  7.952755e-01  1.1239  1.2338  0.5585  0.2691 -0.5469  18.284901
#
#          rmagmax  matchdistarcsecVISTA     RAJ2000    DEJ2000       Ymag  \
# 586    22.100300              0.379852  264.020899 -28.974014  16.423000
# 853    19.594400              0.309217  263.992448 -28.972323  15.387000
# 870    21.987499              0.242112  263.998442 -28.958208  16.980000
# 943    21.538601              0.123783  263.971213 -28.951702  14.385000
# 1246   21.246099              0.166693  264.031455 -26.618322  17.570999
# 1873   20.187901              0.088834  263.953880 -26.623362  16.459000
# 1998   19.887400              0.106509  263.976451 -26.604963  16.433001
# 4490   16.405899              0.092069  263.967719 -24.168153  13.446000
# 6849   21.184900              0.333934  268.605468 -26.644582  17.884001
# 6879   19.956301              0.428229  268.611680 -26.633300  16.639999
# 7015   18.487499              0.426778  268.675833 -26.613801  15.686000
# 7087   21.173800              0.453580  268.621652 -26.606169  17.552999
# 7412   20.972601              0.429584  268.608837 -24.245956  17.594000
# 16119  16.840599              0.070338  277.871975 -29.029063  15.551000
# 33002  13.896300              0.049374  130.629660   0.569540  13.031900
# 34201  13.582600              0.164636  130.629110   1.686760  12.903400
# 36519  20.015900              0.201002  132.873680   0.691630  16.540000
# 39346  18.320700              0.119061  134.356220   0.832430  15.496600
#
#             Jmag     Hmag    Ksmag       GmH  Hmag_predict     Gmy     mark
# 586    15.213000  13.9730  13.5610  6.689301     15.017074  2.8149  outlier
# 853    15.036000  14.7870  12.9790  4.072400     13.092194  2.4176  outlier
# 870    16.160000  15.3510  15.0470  5.026199     16.429577  2.1619  outlier
# 943    14.779000  13.0010  11.1920  5.454799     11.180883  2.7474  outlier
# 1246   16.735001  15.9460  15.6440  4.512000     16.957968  1.6096  outlier
# 1873   15.560000  14.6210  14.2430  4.732000     15.752102  1.6587  outlier
# 1998   15.639000  14.7850  14.4640  4.454800     15.849005  1.6321  outlier
# 4490   12.771000  13.5460  11.6510  2.464401     12.011145  1.6059  outlier
# 6849   16.639999  15.0570  14.1930  5.564200     16.744543  1.8068  outlier
# 6879   15.478000  13.8450  12.9460  5.394099     15.685842  1.7144  outlier
# 7015   14.558000  13.1230  12.4050  5.130401     14.523900  1.6641  outlier
# 7087   16.073999  14.4920  13.6620  6.024501     16.188450  1.8605  outlier
# 7412   16.721001  15.8410  15.4980  4.645601     16.955404  1.7397  outlier
# 16119  17.197001  17.4200  14.4700 -0.614700     14.561511  0.6500  outlier
# 33002  13.048300  14.0626  13.0736 -0.254900     12.585821  0.1498  outlier
# 34201  12.949600  13.4391  12.5995  0.146399     11.951143  0.3299  outlier
# 36519  16.832399  16.6464  15.2063  2.401699     15.431524  1.7607  outlier
# 39346  16.241199  17.3309  14.2478  0.438200     14.446179  1.5145  outlier

# %%
# Many of these outliers have non-standard optical colours. These sources should be flagged beforehand. 
sns.pairplot(test_dataset, hue='mark', vars=['Gmag','BPmRP','BPmG'], plot_kws = {'alpha': 0.6}, size=4, diag_kind='kde')
plt.show()
sns.pairplot(test_dataset, hue='mark', vars=['gmr', 'rmi', 'imz', 'zmy'], plot_kws = {'alpha': 0.6}, size=4, diag_kind='kde')
plt.show()
# Out:
# /Users/rvanderb/anaconda3/envs/ELT/lib/python3.8/site-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
# /Users/rvanderb/anaconda3/envs/ELT/lib/python3.8/site-packages/seaborn/axisgrid.py:2076: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)
